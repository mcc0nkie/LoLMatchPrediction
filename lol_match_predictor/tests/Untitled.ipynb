# %%
import requests
response = requests.get('https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4712344219?api_key=RGAPI-ececaadd-2cde-4cda-af88-f7f3760ae59a')

# %%
response.url
# Out:
# 'https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4712344219?api_key=RGAPI-ececaadd-2cde-4cda-af88-f7f3760ae59a'

# %%
jsn = response.json()

# %%
jsn
# Out:
# {'metadata': {'dataVersion': '2',
#   'matchId': 'NA1_4712344219',
#   'participants': ['8_6Sc0BiXEJa2tZ1qu1P4KnzQuAFyIvbOnhlgdgVPIZfMxMWQbCzSjeFjWjVXANHOmFSSWB9-zqInA',
#    'Rs6kVTL28Ge74lMsUjXcamLBD_VNdTXgd_TSDuZdCwhb-W-6GyszDMPghCch-hqDtNIX0mf87mTUYw',
#    'RnWw0lWQVnZEi2zeGkLNfHVkKgvpvFQL6cdE1jn1z9R1BHW8b5Nh9F0Wq26wGpfbY4hSwvLY3sN9BA',
#    'zB9-iPMGB9y1wYTzhhpJ8zs64fxV-fmJBJtV0osAOyI1X4-M9goKqQpRnU2_8DHwh3lTLLJeVolqcQ',
#    'k48mlNDIbaLEu3jZ-LT2KQb2PLFrYJmaSQcX7S-dXOrRxpxQzrSqdkFYCZW93AVL74onBiqasKw6jw',
#    'e5fiMlHtoT2tX4IimtRrky20CONdpQnB3GfNtj31fDYvW9vsGGSvHX3oNtGcVPeWvtY-17l1eeZrGQ',
#    'MwncnwYAik0p9enfG8r3-Bze33-wz_-6j3vXyunTubmWN9Af9p5kzAs6WAKSuBZqAtAGe-GF171KgQ',
#    '7I_Gn9AjmFOBDKoKHF491AZN3tTI1bnDezebe51Yg9OoR7uFBh5g-gnCGMzhoSqSl2QmJ7ZEpS7Fzw',
#    'SYujK0s5nYCqhNnUNj4LvTsbvwaYn8Es--2KNqHLppdMRHf5tEapbuzknbx_M-0PggisvzhV1y33fA',
#    'BuzP6f8bBPUZHju7eo3kaQoED4IfsvFJTLSAeZuIXb7_8AGdUv5EuuVrTssBGqe5kvwFcYRoPS7dXw']},
#  'info': {'gameCreation': 1689340784418,
# ...

# %%
jsn.keys()
# Out:
# dict_keys(['metadata', 'info'])

# %%
jsn['info']['teams'][1]
# Out:
# {'bans': [{'championId': 45, 'pickTurn': 6},
#   {'championId': 235, 'pickTurn': 7},
#   {'championId': 107, 'pickTurn': 8},
#   {'championId': 114, 'pickTurn': 9},
#   {'championId': 902, 'pickTurn': 10}],
#  'objectives': {'baron': {'first': True, 'kills': 1},
#   'champion': {'first': True, 'kills': 35},
#   'dragon': {'first': False, 'kills': 0},
#   'inhibitor': {'first': True, 'kills': 1},
#   'riftHerald': {'first': True, 'kills': 1},
#   'tower': {'first': True, 'kills': 7}},
#  'teamId': 200,
#  'win': True}

# %%
jsn["info"]["participants"][0]['puuid']
# Out:
# '8_6Sc0BiXEJa2tZ1qu1P4KnzQuAFyIvbOnhlgdgVPIZfMxMWQbCzSjeFjWjVXANHOmFSSWB9-zqInA'
